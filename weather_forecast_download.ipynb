# %%
#globals().clear()

# %%
from herbie import Herbie
from herbie.toolbox import EasyMap, pc
from herbie import paint
import xarray as xr
import os
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import cfgrib
import pandas as pd

# %%
#os.chdir("homedir")
#coordinates for Sau Reservoir
lat = (41.97)
lon = (2.39)

# %% [markdown]
# ## Download

# %% [markdown]
# The model used here is Global Ensemble Forecast System (GEFS): https://www.ncei.noaa.gov/products/weather-climate-models/global-ensemble-forecast

# %% [markdown]
# The GEFS model product could be any of the following:
# - 'atmos.5' - Half degree atmos PRIMARY fields (pgrb2ap5); ~83 most common variables.
# - 'atmos.5b' - Half degree atmos SECONDARY fields (pgrb2bp5); ~500 least common variables
# - 'atmos.25' - Quarter degree atmos PRIMARY fields (pgrb2sp25); ~35 most common variables
# - 'wave' - Global wave products. - 'chem.5'
# - 'chem.5' - Chemistry fields on 0.5 degree grid
# - 'chem.25' - Chemistry fields on 0.25 degree grid

# %% [markdown]
# For our case, following this: https://www.nco.ncep.noaa.gov/pmb/products/gens/, we will need:
# - From atmos.25, surface: "sp", "tp", "sdswrf", "sdlwrf"
# - From atmos.25, heightAboveGround 2m : "t2m", "d2m", "r2", "tmax", "tmin", "u10", "v10", "tcc", "st", "soilw"
# - From atmos.25, heightAboveGround 10m :"u10", "v10",
# - From atmos.25, atmosphere: "tcc"
# - From atmos.25, depthBelowLandLayer at 0-0.1m: "st", "soilw"
# - From atmos.5b, depthBelowLandLayer at 0.1-0.4, 0.4-1, 1-2m: "st", "soilw"

# %% [markdown]
# How do the members work? For the atmos output, member 0 is "c00", which correspond to the control member, then members 1-30 or "p01"-"p30". Another option could be 'avg' or 'mean' for the ensemble mean, 'spr' for ensemble spread.

# %% [markdown]
# How does the lead time work? here is represented by fxx in the herbie function, correspond to the perid that is been forecasted, the resolution is every 3 hours for GEFS. For instance, if I need the forecast for the next coming 2 days starting at 30/01/2025, I need to set fxx from 0 to 48 every 3 hours, in python will be range(0, 49, 3)

# %%
import numpy as np
import xarray as xr
from datetime import datetime, timedelta
from herbie import Herbie
import os
import time

# %%
# Define parameters
initial = datetime.now() - timedelta(days=2)
finish = datetime.now() - timedelta(days=1)
start_date = datetime(initial.year, initial.month, initial.day, 0, 0)
end_date = datetime(finish.year, finish.month, finish.day, 18, 0)
member_list = ["c00"] + [f"p{str(i).zfill(2)}" for i in range(1, 31)]
lead_times = range(0, 49, 3)  # Lead times from 0 to 168, every 3 hours
variables_surface = ["sp", "tp", "sdswrf", "sdlwrf"]
variables_2m = ["t2m", "d2m", "r2", "tmax", "tmin"]
variables_10m = ["u10", "v10"]
variables_atm = ["tcc"]
variables_soil = ["st", "soilw"]
variables_accumulated = ["tp", "sdswrf", "sdlwrf", "tcc"]  # Variables to reset at 00:00
save_dir = "data/"
#lat, lon = 40.0, -105.0  # Example coordinates
lat, lon = 41.97, 2.39

# %%
# Initialize an empty xarray dataset
init_dates = np.array([start_date + timedelta(hours=6*i) for i in range(((end_date - start_date).days + 1) * 4)], dtype="datetime64[ns]")
dataset = xr.Dataset(
    coords={
        "member": range(0,len(member_list)),
        "init": init_dates,
        "lead": range(0,len(lead_times)),
        "latitude": lat,
        "longitude": lon
    }
)

# %%
# Iterate over initialization dates
current_date = start_date
c_init = 0
while current_date <= end_date:
    c_member = 0
    for member in member_list:
        c_lead = 0
        time.sleep(10)
        for lead in lead_times:
                print("date: " + str(current_date) + " member: " + member + " lead: " + str(lead))
            #try:
                # Initialize Herbie for the current date, member, and lead
                H = Herbie(
                    current_date.strftime("%Y-%m-%d %H:%M"),
                    model="gefs",
                    product="atmos.25",
                    member=member,
                    fxx=lead
                )
                
                # Download the data
                path = H.download(save_dir=save_dir)

                # Initialize a dictionary to hold all data for this combination
                data = {}

                # Surface variables
                ds = xr.open_dataset(path, engine="cfgrib", filter_by_keys={'typeOfLevel': 'surface'})
                ds_sel = ds.sel(latitude=lat, longitude=lon, method="nearest")
                for var in variables_surface:
                    #if var in variables_accumulated and current_date.strftime("%H:%M") == "00:00":
                    if var in variables_accumulated and lead == 0:
                        data[var] = np.array(0, dtype="float32")  # Set accumulated variables to 0
                    else:
                        data[var] = ds_sel[var].values

                # 2m height variables
                ds = xr.open_dataset(path, engine="cfgrib", filter_by_keys={'typeOfLevel': 'heightAboveGround', 'level': 2})
                ds_sel = ds.sel(latitude=lat, longitude=lon, method="nearest")
                for var in variables_2m:
                    data[var] = ds_sel[var].values

                # 10m height variables
                ds = xr.open_dataset(path, engine="cfgrib", filter_by_keys={'typeOfLevel': 'heightAboveGround', 'level': 10})
                ds_sel = ds.sel(latitude=lat, longitude=lon, method="nearest")
                for var in variables_10m:
                    data[var] = ds_sel[var].values

                # Atmosphere variables
                for var in variables_atm:
                    #if var in variables_accumulated and current_date.strftime("%H:%M") == "00:00":
                    if var in variables_accumulated and lead == 0:
                        data[var] = np.array(0, dtype="float32")  # Set accumulated variables to 0
                    else:
                        ds = xr.open_dataset(path, engine="cfgrib", filter_by_keys={'typeOfLevel': 'atmosphere'})
                        ds_sel = ds.sel(latitude=lat, longitude=lon, method="nearest")
                        data[var] = ds_sel[var].values

                # Below-land variables
                ds = xr.open_dataset(path, engine="cfgrib", filter_by_keys={'typeOfLevel': 'depthBelowLandLayer'})
                ds_sel = ds.sel(latitude=lat, longitude=lon, method="nearest")
                for var in variables_soil:
                    data[var] = ds_sel[var].values

                #secondary variables (soil for different depths) at 5 degrees
                H = Herbie(
                    current_date.strftime("%Y-%m-%d %H:%M"),
                    model="gefs",
                    product="atmos.5b",
                    member=member,
                    fxx=lead
                )

                # Download the data
                path = H.download(save_dir=save_dir)

                # soil temperature at different depths
                ds = xr.open_dataset(path, engine="cfgrib", filter_by_keys={'paramId': 228139})  # st variable
                ds_sel = ds.sel(latitude=lat, longitude=lon, method="nearest")
                data["st_01"] = ds_sel.sel(depthBelowLandLayer=0.1)['st'].values
                data["st_04"] = ds_sel.sel(depthBelowLandLayer=0.4)['st'].values
                data["st_1"] = ds_sel.sel(depthBelowLandLayer=1)['st'].values

                # Volumetric Soil Moisture Content at different depths
                ds = xr.open_dataset(path, engine="cfgrib", filter_by_keys={'paramId': 260185})  # soilw variable
                ds_sel = ds.sel(latitude=lat, longitude=lon, method="nearest")
                data["soilw_01"] = ds_sel.sel(depthBelowLandLayer=0.1)['soilw'].values
                data["soilw_04"] = ds_sel.sel(depthBelowLandLayer=0.4)['soilw'].values
                data["soilw_1"] = ds_sel.sel(depthBelowLandLayer=1)['soilw'].values

                # Append data to the xarray dataset
                for var, values in data.items():
                    if var not in dataset:
                        dataset[var] = (("member", "init", "lead"), np.full((len(member_list), len(range((end_date - start_date).days + 1))*4, len(lead_times)), np.nan))
                    dataset[var][c_member, c_init, c_lead] = values

                #os.remove(path)

                # Remove the file after processing
                #if os.path.exists(path):
                    #os.remove(path)

                c_lead += 1

            #except Exception as e:
            #    print(f"Error processing {current_date} {member} {lead}: {e}")

        c_member += 1
    c_init += 1

    # Increment the date
    current_date += timedelta(hours=6)

# Final dataset is now built
print(dataset)
# Out:
# date: 2025-01-27 00:00:00 member: c00 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: c00 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p01 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p02 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p03 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p04 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p05 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p06 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p07 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p08 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p09 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p10 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p11 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-27 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-27 00:00:00 member: p12 lead: 0
# ...
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p27 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p27 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p27 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p27 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p27 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p27 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 0
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F00 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 3
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F03 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 6
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 9
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F09 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 12
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F12 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 15
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F15 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 18
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F18 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 21
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F21 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 24
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F24 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 27
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F27 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 30
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F30 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 33
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F33 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 36
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F36 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 39
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F39 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 42
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F42 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 45
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F45 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p28 lead: 48
# ✅ Found ┊ model=gefs ┊ product=atmos.25 ┊ 2025-Jan-28 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# ✅ Found ┊ model=gefs ┊ product=atmos.5b ┊ 2025-Jan-28 00:00 UTC F48 ┊ GRIB2 @ aws ┊ IDX @ aws
# date: 2025-01-28 00:00:00 member: p29 lead: 0
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File ~/miniconda3/lib/python3.12/socket.py:963, in getaddrinfo(host, port, family, type, proto, flags)
#     962 addrlist = []
# --> 963 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     964     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:615, in HTTPSConnection.connect(self)
#     614 sock: socket.socket | ssl.SSLSocket
# --> 615 self.sock = sock = self._new_conn()
#     616 server_hostname: str = self.host
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     202 except socket.gaierror as e:
# --> 203     raise NameResolutionError(self.host, self, e) from e
#     204 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x765dd1f99df0>: Failed to resolve 'noaa-gefs-pds.s3.amazonaws.com' ([Errno -3] Temporary failure in name resolution)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/miniconda3/lib/python3.12/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='noaa-gefs-pds.s3.amazonaws.com', port=443): Max retries exceeded with url: /gefs.20250128/00/atmos/pgrb2sp25/gep29.t00z.pgrb2s.0p25.f000 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x765dd1f99df0>: Failed to resolve 'noaa-gefs-pds.s3.amazonaws.com' ([Errno -3] Temporary failure in name resolution)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[318], line 50
#      47     print("date: " + str(current_date) + " member: " + member + " lead: " + str(lead))
#      48 #try:
#      49     # Initialize Herbie for the current date, member, and lead
# ---> 50     H = Herbie(
#      51         current_date.strftime("%Y-%m-%d %H:%M"),
#      52         model="gefs",
#      53         product="atmos.25",
#      54         member=member,
#      55         fxx=lead
#      56     )
#      58     # Download the data
#      59     path = H.download(save_dir=save_dir)
#
# File ~/miniconda3/lib/python3.12/site-packages/herbie/core.py:266, in Herbie.__init__(self, date, valid_date, model, fxx, product, priority, save_dir, overwrite, verbose, **kwargs)
#     261 self._validate()
#     263 # Ok, now we are ready to look for the GRIB2 file at each of the remote sources.
#     264 # self.grib is the first existing GRIB2 file discovered.
#     265 # self.idx is the first existing index file discovered.
# --> 266 self.grib, self.grib_source = self.find_grib()
#     267 self.idx, self.idx_source = self.find_idx()
#     269 if verbose:
#     270     # ANSI colors added for style points
#
# File ~/miniconda3/lib/python3.12/site-packages/herbie/core.py:474, in Herbie.find_grib(self)
#     472         if grib_path.exists():
#     473             return (grib_path, source)
# --> 474     elif self._check_grib(grib_url):
#     475         return (grib_url, source)
#     477 return (None, None)
#
# File ~/miniconda3/lib/python3.12/site-packages/herbie/core.py:396, in Herbie._check_grib(self, url, min_content_length)
#     381 def _check_grib(self, url: str, min_content_length: int = 10) -> bool:
#     382     """
#     383     Check that the GRIB2 URL exist and is of useful length.
#     384
#    (...)
#     394         essentially turned off this check.
#     395     """
# --> 396     head = requests.head(url)
#     397     check_exists = head.ok
#     398     if check_exists and "Content-Length" in head.raw.info():
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/api.py:100, in head(url, **kwargs)
#      89 r"""Sends a HEAD request.
#      90
#      91 :param url: URL for the new :class:`Request` object.
#    (...)
#      96 :rtype: requests.Response
#      97 """
#      99 kwargs.setdefault("allow_redirects", False)
# --> 100 return request("head", url, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='noaa-gefs-pds.s3.amazonaws.com', port=443): Max retries exceeded with url: /gefs.20250128/00/atmos/pgrb2sp25/gep29.t00z.pgrb2s.0p25.f000 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x765dd1f99df0>: Failed to resolve 'noaa-gefs-pds.s3.amazonaws.com' ([Errno -3] Temporary failure in name resolution)"))

# %%
# Save dataset
dataset.to_netcdf("gefs_"+ str(pd.to_datetime(init_dates[0]).date()))

# %%
#select a day to save
day_save = "2025-01-27"
ds_selected = dataset.sel(init=day_save)
ds_selected.to_netcdf("gefs_"+ day_save)
